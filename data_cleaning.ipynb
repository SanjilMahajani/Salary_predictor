# %%
import pandas as pd
df=pd.read_csv('/Users/sapanamahajani/Desktop/Data/Data_Science_Jobs_in_India.csv')

# %%
df
# Out:
#       Unnamed: 0            company_name       job_title  min_experience  \
# 0              0                     TCS  Data Scientist               2
# 1              1               Accenture  Data Scientist               2
# 2              2                     IBM  Data Scientist               2
# 3              3               Cognizant  Data Scientist               2
# 4              4               Capgemini  Data Scientist               2
# ...          ...                     ...             ...             ...
# 1597        1597  Collabera Technologies  Data Architect               8
# 1598        1598                 Coforge  Data Architect               7
# 1599        1599                 Hitachi  Data Architect              21
# 1600        1600                GE Power  Data Architect               7
# 1601        1601               T-Systems  Data Architect              16
#
#      avg_salary min_salary max_salary  num_of_salaries
# ...

# %% [markdown]
# Exploring the data a liitle bit

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'company_name', 'job_title', 'min_experience',
#        'avg_salary', 'min_salary', 'max_salary', 'num_of_salaries'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#                 company_name       job_title  min_experience avg_salary  \
# 0                        TCS  Data Scientist               2       7.8L
# 1                  Accenture  Data Scientist               2      12.8L
# 2                        IBM  Data Scientist               2      13.4L
# 3                  Cognizant  Data Scientist               2       9.8L
# 4                  Capgemini  Data Scientist               2       8.6L
# ...                      ...             ...             ...        ...
# 1597  Collabera Technologies  Data Architect               8      17.0L
# 1598                 Coforge  Data Architect               7      27.1L
# 1599                 Hitachi  Data Architect              21      40.0L
# 1600                GE Power  Data Architect               7      16.7L
# 1601               T-Systems  Data Architect              16      33.3L
#
#      min_salary max_salary  num_of_salaries
# 0          4.5L      16.0L              841
# ...

# %%
df['company_name'].nunique()
# Out:
# 642

# %%
df['avg_salary'].unique()
# Out:
# array(['7.8L', '12.8L', '13.4L', '9.8L', '8.6L', '9.3L', '9.7L', '7.6L',
#        '15.9L', '14.2L', '14.6L', '28.1L', '14.8L', '7.4L', '20.6L',
#        '11.6L', '16.6L', '12.4L', '10.6L', '28.3L', '10.0L', '32.1L',
#        '12.2L', '14.4L', '15.6L', '11.4L', '20.9L', '27.7L', '20.5L',
#        '14.0L', '17.7L', '15.3L', '10.4L', '16.9L', '16.3L', '21.9L',
#        '10.5L', '12.6L', '17.4L', '14.3L', '9.0L', '10.7L', '23.2L',
#        '4.5L', '14.1L', '7.7L', '18.2L', '8.9L', '4.9L', '16.0L', '19.2L',
#        '15.4L', '12.1L', '7.1L', '19.0L', '11.9L', '17.0L', '12.9L',
#        '15.1L', '14.9L', '13.5L', '19.6L', '12.5L', '8.0L', '13.0L',
#        '23.6L', '8.1L', '9.4L', '5.1L', '11.5L', '16.2L', '8.2L', '22.8L',
#        '11.7L', '10.9L', '10.8L', '10.2L', '8.5L', '6.9L', '4.7L', '9.1L',
#        '17.3L', '5.2L', '8.3L', '17.9L', '6.6L', '7.0L', '16.4L', '9.6L',
#        '20.3L', '7.9L', '23.4L', '13.9L', '8.7L', '29.4L', '19.4L',
# ...

# %%
df['max_salary'].unique()
# Out:
# array(['16.0L', '23.0L', '25.0L', '18.0L', '14.6L', '24.0L', '18.2L',
#        '15.4L', '26.9L', '20.3L', '50.0L', '21.5L', '12.0L', '26.2L',
#        '20.9L', '20.0L', '22.5L', '18.7L', '41.0L', '15.5L', '60.0L',
#        '26.5L', '30.0L', '21.8L', '22.0L', '27.0L', '45.0L', '31.0L',
#        '21.0L', '26.0L', '22.2L', '13.8L', '39.0L', '36.0L', '13.0L',
#        '15.2L', '42.0L', '7.0L', '17.2L', '23.9L', '15.0L', '35.0L',
#        '17.0L', '19.0L', '16.3L', '31.2L', '16.7L', '23.7L', '18.5L',
#        '32.5L', '19.4L', '23.4L', '11.5L', '23.5L', '25.3L', '16.6L',
#        '17.6L', '12.7L', '28.0L', '32.1L', '14.4L', '8.0L', '16.2L',
#        '24.4L', '14.0L', '30.3L', '15.6L', '20.5L', '13.7L', '12.3L',
#        '9.0L', '18.6L', '24.2L', '12.5L', '6.0L', '7.9L', '9.2L', '10.0L',
#        '14.5L', '44.0L', '17.5L', '27.5L', '20.6L', '13.5L', '19.7L',
#        '10.8L', '8.5L', '30.1L', '25.8L', '20.8L', '20.1L', '74.5L',
# ...

# %%
df['min_salary'].unique()
# Out:
# array(['4.5L', '5.8L', '5.3L', '5.0L', '4.8L', '4.1L', '10.0L', '7.0L',
#        '6.0L', '9.5L', '8.3L', '15.0L', '6.5L', '9.0L', '11.0L', '6.7L',
#        '17.8L', '4.4L', '13.0L', '5.5L', '7.1L', '5.6L', '9.9L', '6.9L',
#        '13.5L', '12.0L', '7.6L', '10.8L', '7.5L', '14.7L', '2.0L', '8.5L',
#        '7.4L', '5.2L', '8.2L', '3.0L', '7.2L', '5.4L', '8.0L', '6.6L',
#        '14.0L', '7.8L', '12.1L', '4.0L', '11.5L', '4.2L', '13.2L', '7.9L',
#        '7.7L', '3.2L', '5.1L', '3.3L', '2.4L', '7.3L', '11.2L', '6.2L',
#        '6.4L', '15.1L', '11.4L', '14.5L', '13.6L', '5.7L', '6.3L',
#        '13.8L', '20.0L', '4.9L', '4.3L', '16.5L', '8.4L', '10.2L', '3.5L',
#        '3.6L', '10.5L', '2.7L', '2.3L', '4.7L', '3.8L', '3.4L', '6.8L',
#        '1.6L', '6.1L', '4.6L', '3.9L', '2.8L', '3.1L', '1.2L', '8.1L',
#        '2.5L', '2.1L', '2.9L', '10.1L', '2.2L', '2.6L', '1.1L', '1.8L',
#        '3.7L', '1.5L', '1.0L', '1.9L', '1.7L', '0.2L', '1.4L', '8.8L',
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                 company_name       job_title  min_experience avg_salary  \
# 0                        TCS  Data Scientist               2       7.8L
# 1                  Accenture  Data Scientist               2      12.8L
# 2                        IBM  Data Scientist               2      13.4L
# 3                  Cognizant  Data Scientist               2       9.8L
# 4                  Capgemini  Data Scientist               2       8.6L
# ...                      ...             ...             ...        ...
# 1597  Collabera Technologies  Data Architect               8      17.0L
# 1598                 Coforge  Data Architect               7      27.1L
# 1599                 Hitachi  Data Architect              21      40.0L
# 1600                GE Power  Data Architect               7      16.7L
# 1601               T-Systems  Data Architect              16      33.3L
#
#      min_salary max_salary  num_of_salaries
# 0          4.5L      16.0L              841
# ...

# %% [markdown]
# Salary Parsing

# %%
df['avg_salary'] = df['avg_salary'].apply(lambda x: x.replace('L',''))
df['min_salary'] = df['min_salary'].apply(lambda x: x.replace('L',''))
df['max_salary'] = df['max_salary'].apply(lambda x: x.replace('L',''))

# %%
df
# Out:
#                 company_name       job_title  min_experience avg_salary  \
# 0                        TCS  Data Scientist               2        7.8
# 1                  Accenture  Data Scientist               2       12.8
# 2                        IBM  Data Scientist               2       13.4
# 3                  Cognizant  Data Scientist               2        9.8
# 4                  Capgemini  Data Scientist               2        8.6
# ...                      ...             ...             ...        ...
# 1597  Collabera Technologies  Data Architect               8       17.0
# 1598                 Coforge  Data Architect               7       27.1
# 1599                 Hitachi  Data Architect              21       40.0
# 1600                GE Power  Data Architect               7       16.7
# 1601               T-Systems  Data Architect              16       33.3
#
#      min_salary max_salary  num_of_salaries
# 0           4.5       16.0              841
# ...

# %%
df.to_csv('/Users/sapanamahajani/Desktop/Data/cleansed_data.csv',index=False)
